# %%
# !python --version
# Out:
# Python 3.10.8

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv('gofood_dataset.csv')
dataset
# Out:
#            merchant_name merchant_area           category            display  \
# 0      330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti          Signature
# 1      330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti          Signature
# 2      330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti          Signature
# 3      330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti          Signature
# 4      330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti          Signature
# ...                  ...           ...                ...                ...
# 45190   Zeger!, Sidoarjo      surabaya       Minuman/Kopi  1L ZEGER BANGET !
# 45191   Zeger!, Sidoarjo      surabaya       Minuman/Kopi  1L ZEGER BANGET !
# 45192   Zeger!, Sidoarjo      surabaya       Minuman/Kopi  1L ZEGER BANGET !
# 45193   Zeger!, Sidoarjo      surabaya       Minuman/Kopi  1L ZEGER BANGET !
# 45194   Zeger!, Sidoarjo      surabaya       Minuman/Kopi  1L ZEGER BANGET !
#
# ...

# %%
dataset.head(11)
# Out:
#         merchant_name merchant_area           category    display  \
# 0   330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 1   330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 2   330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 3   330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 4   330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 5   330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 6   330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 7   330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 8   330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 9   330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 10  330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
#
#                                   product    price  discount_price  \
# 0   Hot Almara Kopi (kopi Susu Gula Aren)  20000.0             NaN
# ...

# %%
dataset.tail(11)
# Out:
#           merchant_name merchant_area      category            display  \
# 45184  Zeger!, Sidoarjo      surabaya  Minuman/Kopi      Coffee Series
# 45185  Zeger!, Sidoarjo      surabaya  Minuman/Kopi  1L ZEGER BANGET !
# 45186  Zeger!, Sidoarjo      surabaya  Minuman/Kopi  1L ZEGER BANGET !
# 45187  Zeger!, Sidoarjo      surabaya  Minuman/Kopi  1L ZEGER BANGET !
# 45188  Zeger!, Sidoarjo      surabaya  Minuman/Kopi  1L ZEGER BANGET !
# 45189  Zeger!, Sidoarjo      surabaya  Minuman/Kopi  1L ZEGER BANGET !
# 45190  Zeger!, Sidoarjo      surabaya  Minuman/Kopi  1L ZEGER BANGET !
# 45191  Zeger!, Sidoarjo      surabaya  Minuman/Kopi  1L ZEGER BANGET !
# 45192  Zeger!, Sidoarjo      surabaya  Minuman/Kopi  1L ZEGER BANGET !
# 45193  Zeger!, Sidoarjo      surabaya  Minuman/Kopi  1L ZEGER BANGET !
# 45194  Zeger!, Sidoarjo      surabaya  Minuman/Kopi  1L ZEGER BANGET !
#
#                          product    price  discount_price  isDiscount  \
# ...

# %%
#dataset.colums()

# %%
dataset.shape
# Out:
# (45195, 9)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45195 entries, 0 to 45194
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   merchant_name   45195 non-null  object
#  1   merchant_area   45195 non-null  object
#  2   category        45195 non-null  object
#  3   display         45195 non-null  object
#  4   product         45195 non-null  object
#  5   price           45195 non-null  float64
#  6   discount_price  2738 non-null   float64
#  7   isDiscount      45195 non-null  int64
#  8   description     21720 non-null  object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 3.1+ MB

# %% [markdown]
# **Melihat data kosong / data missing**

# %%
dataset.isnull().sum()
# Out:
# merchant_name         0
# merchant_area         0
# category              0
# display               0
# product               0
# price                 0
# discount_price    42457
# isDiscount            0
# description       23475
# dtype: int64

# %%
#dataset.discount_price.value_counts()
dataset.discount_price.value_counts().sum()
# Out:
# 2738

# %%
discount_missing = dataset['discount_price'].isnull().mean()*100
print('Total persentase data missing kolom description : {:.2f}%'.format(discount_missing))
# Out:
# Total persentase data missing kolom description : 93.94%

# %%
dataset.description.value_counts().sum()
# Out:
# 21720

# %%
description_missing = dataset['description'].isnull().mean()*100
print('Total persentase data missing kolom description : {:.2f}%'.format(description_missing))
# Out:
# Total persentase data missing kolom description : 51.94%

# %%
sns.heatmap(dataset.isnull(), yticklabels = False, cbar = False, cmap = "viridis");

# %% [markdown]
# **MENGISI DATA YANG KOSONG, pada kolom discount_price**

# %%
dataset['discount_price'].fillna(0, inplace = True)

# %%
dataset.isnull().sum()
# Out:
# merchant_name         0
# merchant_area         0
# category              0
# display               0
# product               0
# price                 0
# discount_price        0
# isDiscount            0
# description       23475
# dtype: int64

# %%
dataset
# Out:
#            merchant_name merchant_area           category            display  \
# 0      330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti          Signature
# 1      330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti          Signature
# 2      330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti          Signature
# 3      330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti          Signature
# 4      330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti          Signature
# ...                  ...           ...                ...                ...
# 45190   Zeger!, Sidoarjo      surabaya       Minuman/Kopi  1L ZEGER BANGET !
# 45191   Zeger!, Sidoarjo      surabaya       Minuman/Kopi  1L ZEGER BANGET !
# 45192   Zeger!, Sidoarjo      surabaya       Minuman/Kopi  1L ZEGER BANGET !
# 45193   Zeger!, Sidoarjo      surabaya       Minuman/Kopi  1L ZEGER BANGET !
# 45194   Zeger!, Sidoarjo      surabaya       Minuman/Kopi  1L ZEGER BANGET !
#
# ...

# %% [markdown]
# **TOP 10 Merchant Revenue**

# %%
dsrevenue = dataset.groupby(['merchant_name', 'merchant_area']).sum().sort_values(by = 'price', ascending = False)
dsrevenue.head(10)
# Out:
#                                                price  discount_price  \
# merchant_name              merchant_area
# Holywings Backyard, Kemang jakarta        54904300.0             0.0
# Holywings Gold Basra       surabaya       47362040.0             0.0
# Holywings, Medan           medan          47074280.0             0.0
# Holywings, Kertajaya       surabaya       45946560.0             0.0
# Suans Bakery               medan          36458150.0             0.0
# The Garrison, Kemang       jakarta        34962840.0             0.0
# Grand Liberty Restaurant   medan          34894000.0       1226000.0
# Holland Bakery, Tropodo    surabaya       30873200.0             0.0
# Holland Bakery, Thamrin    surabaya       29390800.0             0.0
# Bika Ambon Zulaikha        medan          25747608.0             0.0
#
#                                           isDiscount
# merchant_name              merchant_area
# Holywings Backyard, Kemang jakarta                 0
# ...

# %% [markdown]
# **BOTTOM 10 Merchant Revenue**

# %%
dsrevenue = dataset.groupby(['merchant_name', 'merchant_area']).sum().sort_values(by = 'price', ascending = True)
dsrevenue.head(10)
# Out:
#                                      price  discount_price  isDiscount
# merchant_name       merchant_area
# Gorengan Bu Aidah   medan          17500.0             0.0           0
# Goorengan Indonesia surabaya       20000.0             0.0           0
# Warung Teguh        medan          38000.0             0.0           0
# JACK DONUT          jakarta        44500.0         17500.0           5
# Subsidi             surabaya       45980.0         31980.0           3
# Slea Kitchen        surabaya       49500.0             0.0           0
# Dapur Pancali       surabaya       50000.0             0.0           0
# Warung Babe         jakarta        53000.0             0.0           0
# Bakso Lava          surabaya       70000.0             0.0           0
# Kemek Nyok          jakarta        76000.0             0.0           0

# %% [markdown]
# **TOP 10 Merchant Revenue in Surabaya**

# %%
dst_1 = dataset[dataset['merchant_area'].str.contains('surabaya')]
dst_1 = dst_1.groupby(['merchant_name']).sum().sort_values(by = 'price', ascending = False)
dst_1.head(10)
# Out:
#                                 price  discount_price  isDiscount
# merchant_name
# Holywings Gold Basra       47362040.0             0.0           0
# Holywings, Kertajaya       45946560.0             0.0           0
# Holland Bakery, Tropodo    30873200.0             0.0           0
# Holland Bakery, Thamrin    29390800.0             0.0           0
# Corica, Biliton            18407600.0             0.0           0
# Holland Bakery Indrapura   13816200.0             0.0           0
# Burger King, Sidoarjo      12636724.0       3122006.0          44
# Laritta Bakery, Manukan    11787050.0         22500.0           4
# McDonald's, Merr Surabaya  10993000.0        772000.0          14
# Suka Kepiting              10131000.0       7307200.0          78

# %% [markdown]
# **Bottom 10 Merchant Revenue in Surabaya**

# %%
dst_2 = dataset[dataset['merchant_area'].str.contains('surabaya')]
dst_2 = dst_2.groupby(['merchant_name']).sum().sort_values(by = 'price', ascending = True)
dst_2.head(10)
# Out:
#                         price  discount_price  isDiscount
# merchant_name
# Goorengan Indonesia   20000.0             0.0           0
# Subsidi               45980.0         31980.0           3
# Slea Kitchen          49500.0             0.0           0
# Dapur Pancali         50000.0             0.0           0
# Bakso Lava            70000.0             0.0           0
# Bakso Kenari          94000.0             0.0           0
# WARUNG MBAKNET       118000.0             0.0           0
# Lanuli Mocktail      120000.0             0.0           0
# BasrenG GonjrenG     123800.0             0.0           0
# Father Kafe          133000.0             0.0           0

# %% [markdown]
# **Top 10 Ordered Chinese Food in Gofood**

# %%
dst_3 = dataset[dataset['product'].str.contains('Chinese')]
dst_3 = dst_3.groupby(['category']).count().sort_values(by = 'price', ascending = False)
dst_3.head(10)
# Out:
#                               merchant_name  merchant_area  display  product  \
# category
# Aneka nasi/Chinese/Seafood              318            318      318      318
# Chinese                                 197            197      197      197
# Ayam & bebek/Chinese/Seafood            190            190      190      190
# Aneka nasi/Barat/Chinese                171            171      171      171
# Aneka nasi/Bakmie/Chinese               122            122      122      122
# Chinese/Jepang/Korea                    116            116      116      116
# Bakmie/Chinese/Aneka nasi                83             83       83       83
# Chinese/Minuman/Seafood                  78             78       78       78
# Seafood/Chinese/Minuman                  50             50       50       50
# Ayam & bebek/Seafood/Chinese             48             48       48       48
#
#                               price  discount_price  isDiscount  description
# category
# ...

# %%
sns.barplot(
    x = "merchant_name",
    y = "product",
    data = dst_3
);

plt.title('Total Product Sales')
# Out:
# Text(0.5, 1.0, 'Total Product Sales')

# %%
cek = dataset[dataset['merchant_name'].str.contains('369 Shanghai, Jemursari')]
cek = cek.groupby(['product']).count().sort_values(by = 'price', ascending = False)
cek.head(10)
# Out:
#                         merchant_name  merchant_area  category  display  \
# product
# Babat Hitam                         1              1         1        1
# Nasi Putih                          1              1         1        1
# Mie Goreng Pork / CK                1              1         1        1
# Mie Hokkian                         1              1         1        1
# Mie Kou Rou                         1              1         1        1
# Mie Polos                           1              1         1        1
# Mie Zhajiang                        1              1         1        1
# Nasi Cap Jay                        1              1         1        1
# Nasi Goreng 369 (Pork)              1              1         1        1
# Nasi Goreng Chasiu                  1              1         1        1
#
#                         price  discount_price  isDiscount  description
# product
# Babat Hitam                 1               1           1            0
# ...
