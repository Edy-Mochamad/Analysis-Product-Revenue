# %%
# !conda info
# Out:
#      active environment : env_gofood
#     active env location : C:\Users\ASUS\anaconda3\envs\env_gofood
#             shell level : 1
#        user config file : C:\Users\ASUS\.condarc
#  populated config files : C:\Users\ASUS\.condarc
#           conda version : 22.9.0
#     conda-build version : 3.22.0
#          python version : 3.9.13.final.0
#        virtual packages : __win=0=0
#                           __archspec=1=x86_64
#        base environment : C:\Users\ASUS\anaconda3  (writable)
#       conda av data dir : C:\Users\ASUS\anaconda3\etc\conda
#   conda av metadata url : None
#            channel URLs : https://repo.anaconda.com/pkgs/main/win-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/win-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#                           https://repo.anaconda.com/pkgs/msys2/win-64
# ...

# %%
# !python --version
# Out:
# Python 3.10.8

# %%
# %conda install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\Users\ASUS\anaconda3\envs\env_gofood
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pandas-1.5.2               |  py310h4ed8f06_0        10.5 MB
#     ------------------------------------------------------------
#                                            Total:        10.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/win-64::blas-1.0-mkl None
#   bottleneck         pkgs/main/win-64::bottleneck-1.3.5-py310h9128911_0 None
#   intel-openmp       pkgs/main/win-64::intel-openmp-2021.4.0-haa95532_3556 None
#   mkl                pkgs/main/win-64::mkl-2021.4.0-haa95532_640 None
# ...

# %%
# %conda install matplotlib
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\Users\ASUS\anaconda3\envs\env_gofood
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     contourpy-1.0.5            |  py310h59b6b97_0         159 KB
#     matplotlib-3.6.2           |  py310haa95532_0           9 KB
#     matplotlib-base-3.6.2      |  py310h1094b8e_0         6.5 MB
#     ------------------------------------------------------------
#                                            Total:         6.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli             pkgs/main/win-64::brotli-1.0.9-h2bbff1b_7 None
#   brotli-bin         pkgs/main/win-64::brotli-bin-1.0.9-h2bbff1b_7 None
#   contourpy          pkgs/main/win-64::contourpy-1.0.5-py310h59b6b97_0 None
# ...

# %%
# %conda install numpy
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 22.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
# %conda install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\Users\ASUS\anaconda3\envs\env_gofood
#
#   added / updated specs:
#     - seaborn
#
#
# The following NEW packages will be INSTALLED:
#
#   seaborn            pkgs/main/win-64::seaborn-0.12.1-py310haa95532_0 None
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 22.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('gofood_dataset.csv')
dataset
# Out:
#            merchant_name merchant_area           category            display  \
# 0      330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti          Signature
# 1      330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti          Signature
# 2      330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti          Signature
# 3      330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti          Signature
# 4      330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti          Signature
# ...                  ...           ...                ...                ...
# 45190   Zeger!, Sidoarjo      surabaya       Minuman/Kopi  1L ZEGER BANGET !
# 45191   Zeger!, Sidoarjo      surabaya       Minuman/Kopi  1L ZEGER BANGET !
# 45192   Zeger!, Sidoarjo      surabaya       Minuman/Kopi  1L ZEGER BANGET !
# 45193   Zeger!, Sidoarjo      surabaya       Minuman/Kopi  1L ZEGER BANGET !
# 45194   Zeger!, Sidoarjo      surabaya       Minuman/Kopi  1L ZEGER BANGET !
#
# ...

# %%
dataset.head(11)
# Out:
#         merchant_name merchant_area           category    display  \
# 0   330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 1   330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 2   330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 3   330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 4   330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 5   330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 6   330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 7   330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 8   330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 9   330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 10  330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
#
#                                   product    price  discount_price  \
# 0   Hot Almara Kopi (kopi Susu Gula Aren)  20000.0             NaN
# ...

# %%
dataset.tail(11)
# Out:
#           merchant_name merchant_area      category            display  \
# 45184  Zeger!, Sidoarjo      surabaya  Minuman/Kopi      Coffee Series
# 45185  Zeger!, Sidoarjo      surabaya  Minuman/Kopi  1L ZEGER BANGET !
# 45186  Zeger!, Sidoarjo      surabaya  Minuman/Kopi  1L ZEGER BANGET !
# 45187  Zeger!, Sidoarjo      surabaya  Minuman/Kopi  1L ZEGER BANGET !
# 45188  Zeger!, Sidoarjo      surabaya  Minuman/Kopi  1L ZEGER BANGET !
# 45189  Zeger!, Sidoarjo      surabaya  Minuman/Kopi  1L ZEGER BANGET !
# 45190  Zeger!, Sidoarjo      surabaya  Minuman/Kopi  1L ZEGER BANGET !
# 45191  Zeger!, Sidoarjo      surabaya  Minuman/Kopi  1L ZEGER BANGET !
# 45192  Zeger!, Sidoarjo      surabaya  Minuman/Kopi  1L ZEGER BANGET !
# 45193  Zeger!, Sidoarjo      surabaya  Minuman/Kopi  1L ZEGER BANGET !
# 45194  Zeger!, Sidoarjo      surabaya  Minuman/Kopi  1L ZEGER BANGET !
#
#                          product    price  discount_price  isDiscount  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45195 entries, 0 to 45194
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   merchant_name   45195 non-null  object
#  1   merchant_area   45195 non-null  object
#  2   category        45195 non-null  object
#  3   display         45195 non-null  object
#  4   product         45195 non-null  object
#  5   price           45195 non-null  float64
#  6   discount_price  2738 non-null   float64
#  7   isDiscount      45195 non-null  int64
#  8   description     21720 non-null  object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 3.1+ MB

# %%
dataset.isna().sum()
# Out:
# merchant_name         0
# merchant_area         0
# category              0
# display               0
# product               0
# price                 0
# discount_price    42457
# isDiscount            0
# description       23475
# dtype: int64
